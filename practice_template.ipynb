# %% [markdown]
# # Practice notebook
#
# Scaffolded by the **@Tutor** persona (`new <topic>`), from `practice_template.ipynb`.
#
# **How to use it:** run the cells top to bottom (`Shift+Enter`). The `%%ai` cells ask the configured model for an explanation and a set of exercises about your topic; solve them in the empty cells that follow. Re-run an `%%ai` cell any time you want a fresh set. The AI writes the explanations and exercises here, and it can be wrong — run everything and check it.
#
# > The `%%ai` cells need a model: local **Ollama** (default) or **OpenRouter** — see [`SETUP.md`](SETUP.md). The alias cell below points at the repo's default local model; change it to any model from `ollama list`.

# %%
TOPIC = "replace me"  # the Tutor persona pre-sets this when scaffolding
print(f"Practicing: {TOPIC}")

# %%
# %load_ext jupyter_ai_magic_commands
# The %%ai cells below need a model. This block auto-picks an installed Ollama
# model so it usually "just works" — but you can force one: set MODEL yourself
# (keep the ollama_chat/ prefix), or use an openrouter/... id.
# The %%ai cells use {TOPIC} interpolation from the variable above — if your
# jupyter-ai version doesn't substitute it, type the topic in by hand.
import subprocess
MODEL = "ollama_chat/gemma4:12b"  # change me to any name from `ollama list`
try:
    out = subprocess.run(
        ["ollama", "list"], capture_output=True, text=True, timeout=5
    ).stdout
    installed = [ln.split()[0] for ln in out.splitlines()[1:] if ln.split()]
    default = MODEL.split("/", 1)[-1]
    if default in installed:        # repo default is installed — use it
        MODEL = "ollama_chat/" + default
    elif installed:                 # not there — use the first model you have
        MODEL = "ollama_chat/" + installed[0]
except Exception:
    pass  # no ollama / offline / timeout — keep the default above
get_ipython().run_line_magic("ai", f"alias tutor {MODEL}")
print(f"@Tutor is using {MODEL} — change it by editing MODEL above.")

# %% [markdown]
# ## 1. The idea
#
# First, an explanation pitched at a learner — with small runnable examples.

# %%
# %%ai tutor
# Explain "{TOPIC}" in Python to someone learning the language.
# Keep it under 300 words, include 2 short runnable code examples,
# and finish with one common mistake beginners make.

# %%
# Try the examples from the explanation here.

# %% [markdown]
# ## 2. Exercises
#
# Now generate exercises — **without** solutions. Write your answers in the cells that follow.

# %%
# %%ai tutor
# Create exactly 3 practice exercises about "{TOPIC}" in Python, ordered from
# easy to harder. Number them 1–3. For each: a short task description and, if
# helpful, a tiny starter snippet. Do NOT include solutions or hints.

# %%
# Exercise 1 — your solution

# %%
# Exercise 2 — your solution

# %%
# Exercise 3 — your solution

# %% [markdown]
# ## 3. Get your work reviewed
#
# Paste your solution into the `%%ai` cell below (replacing the placeholder) and run it — or copy your code into the chat panel and ask **@Tutor** to review it there.

# %%
# %%ai tutor
# Review this solution to one of the "{TOPIC}" exercises. Point out bugs,
# style issues, and one way to improve it — be encouraging and specific.
#
# ```python
# # ⬇️ paste your solution here, then run this cell
# ```

# %% [markdown]
# ## Keep going
#
# - Want a harder set? Re-run the exercises cell, or edit its prompt (e.g. *“make them interview-level”*).
# - New topic: in the chat, `@Tutor new <topic>`.
# - See what you've done so far: `@Tutor list`.
